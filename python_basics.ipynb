# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
import math

'''def add(x,y):
    z = x + y
    return z'''

'''def subtract(x,y):
  z =  x - y
  return z'''

def theorem(x,y):
  z = math.sqrt((x**2) + (y**2))
  return z

#value = add(x,y)
#print(type(value))
#print(f"Final operation value is {value}")
x = int(input("Enter first value :"))
y = int(input("Enter second value :"))
theorem_value = theorem(x,y)
print(f"Hypotenus : {theorem_value}")
# Out:
# Enter first value :3
# Enter second value :4
# Hypotenus : 5.0

# %%
text = 'I love AI and data science'
list = text.split()
for words in list:
  print(words)
# Out:
# I
# love
# AI
# and
# data
# science
